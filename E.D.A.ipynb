# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/hp/Downloads/archive (6)/PMC Hospital Infrastructure.csv")
df
# Out:
#     City Name                      Zone Name                 Ward Name  \
# 0        Pune      kasba - vishrambagwada WO                Ambil Odha
# 1        Pune               Aundh - Baner WO                     Aundh
# 2        Pune               Aundh - Baner WO                    Bopodi
# 3        Pune  Ghole Road - Shivaji Nagar WO     Shivaji Nagar Station
# 4        Pune          Hadapsar - Mundhwa WO                  Hadapsar
# ..        ...                            ...                       ...
# 732      Pune                              1          DHOLE-PATIL ROAD
# 733      Pune                              1  NAGAR ROAD- VADGOANSHERI
# 734      Pune                              3             SINGHARD ROAD
# 735      Pune                              1          DHOLE-PATIL ROAD
# 736      Pune                              4          HADAPSAR-MUNDHWA
#
#      Zone No.  Ward No.                                      Facility Name  \
# 0         5.0       NaN  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1         2.0       NaN                   Aundh Kuti Maternity Home, Aundh
# 2         2.0       NaN  Late Draupadabai Murlidhar Khedekar Maternity ...
# 3         2.0       NaN                       Dr. Dalvi, PMC Joint Project
# 4         4.0       NaN     Late Anna Saheb Magar Maternity Home, Hadapsar
# ..        ...       ...                                                ...
# 732       1.0       NaN                  Nityashraddha  Life Care Hospital
# 733       1.0       NaN                             Jeevnjyot Nursing Home
# 734       3.0       NaN                              Dr. Pathak Eye Clinic
# 735       1.0       NaN                             Bliz fertility center
# 736       4.0       NaN                             Shree Samarth Hospital
#
#     Type  (Hospital / Nursing Home / Lab)  Class : (Public / Private)  \
# 0               Hospital (Maternity Home)                      Public
# 1               Hospital (Maternity Home)                      Public
# 2               Hospital (Maternity Home)                      Public
# 3               Hospital (Maternity Home)                      Public
# 4               Hospital (Maternity Home)                      Public
# ..                                    ...                         ...
# 732                               GENERAL                     private
# 733                               GENERAL                     private
# 734                          OPTHALMOLOGY                     private
# 735                               GENERAL                     private
# 736                               MAT+GEN                     private
#
#     Pharmacy Available : Yes/No Number of Beds in Emergency Wards   \
# 0                           Yes                                  0
# 1                           Yes                                  0
# 2                           Yes                                  0
# 3                           Yes                                  0
# 4                           Yes                                  0
# ..                          ...                                ...
# 732                        N.A.                               N.A.
# 733                        N.A.                               N.A.
# 734                        N.A.                               N.A.
# 735                        N.A.                               N.A.
# 736                        N.A.                               N.A.
#
#      Number of Beds in facility type Number of Doctors / Physicians  \
# 0                                 10                              2
# 1                                 14                              2
# 2                                 16                              2
# 3                                 30                              4
# 4                                 20                              2
# ..                               ...                            ...
# 732                               20                           N.A.
# 733                               10                           N.A.
# 734                                2                           N.A.
# 735                                3                           N.A.
# 736                                8                           N.A.
#
#     Number of Nurses Number of Midwives Professional   \
# 0                  4                                1
# 1                  5                                2
# 2                  4                                9
# 3                  7                                9
# 4                  3                                6
# ..               ...                              ...
# 732             N.A.                             N.A.
# 733             N.A.                             N.A.
# 734             N.A.                             N.A.
# 735             N.A.                             N.A.
# 736             N.A.                             N.A.
#
#     Average Monthly Patient Footfall Ambulance Service Available  \
# 0                               4500                         Yes
# 1                               2500                         Yes
# 2                               1900                         Yes
# 3                               2400                         Yes
# 4                               4500                         Yes
# ..                               ...                         ...
# 732                             N.A.                        N.A.
# 733                             N.A.                        N.A.
# 734                             N.A.                        N.A.
# 735                             N.A.                        N.A.
# 736                             N.A.                        N.A.
#
#     Count of Ambulance
# 0                    1
# 1                    1
# 2                    1
# 3                    2
# 4                    1
# ..                 ...
# 732               N.A.
# 733               N.A.
# 734               N.A.
# 735               N.A.
# 736               N.A.
#
# [737 rows x 17 columns]

# %%
df.select_dtypes(include=object).describe()
# Out:
#        City Name Zone Name      Ward Name         Facility Name  \
# count        737       705            735                   737
# unique         1        18             80                   708
# top         Pune         2  KASBA-VISHRAM  Dhanwantari Hospital
# freq         737       161             81                     4
#
#        Type  (Hospital / Nursing Home / Lab)  Class : (Public / Private)  \
# count                                    737                         737
# unique                                    43                           2
# top                                  MAT+GEN                     private
# freq                                     278                         663
#
#        Pharmacy Available : Yes/No Number of Beds in Emergency Wards   \
# count                          737                                737
# unique                           3                                  2
# top                           N.A.                               N.A.
# freq                           603                                663
#
#        Number of Doctors / Physicians Number of Nurses  \
# count                             737              737
# unique                              6               12
# top                              N.A.             N.A.
# freq                              663              663
#
#        Number of Midwives Professional  Average Monthly Patient Footfall  \
# count                               737                              734
# unique                               12                               36
# top                                N.A.                             N.A.
# freq                                663                              663
#
#        Ambulance Service Available Count of Ambulance
# count                          737                737
# unique                           4                  6
# top                           N.A.               N.A.
# freq                           617                663

# %%
df.describe()
# Out:
#          Zone No.  Ward No.  Number of Beds in facility type
# count  692.000000       0.0                       737.000000
# mean     3.013006       NaN                        21.721845
# std      1.401303       NaN                        63.657392
# min      1.000000       NaN                         0.000000
# 25%      2.000000       NaN                         4.000000
# 50%      3.000000       NaN                         7.000000
# 75%      4.000000       NaN                        15.000000
# max      5.000000       NaN                       831.000000

# %%
avg_beds_by_types = df.pivot_table(
    values="Number of Beds in facility type",
    index="Type  (Hospital / Nursing Home / Lab)",
    aggfunc="mean"
).round(0)
avg_beds_by_types.sort_values(by="Number of Beds in facility type", ascending=False, inplace=True)
avg_beds_by_types
# Out:
#                                         Number of Beds in facility type
# Type  (Hospital / Nursing Home / Lab)
# Hospital (General)                                                450.0
# Hospital (Infectious Disease)                                     200.0
# speciality                                                        167.0
# HOMEOPATHIC                                                       100.0
# AURVEDIC                                                           70.0
# CARDIOLOGY                                                         57.0
# CANSER                                                             50.0
# maternity                                                          32.0
# Specility Both                                                     31.0
# Hospital (Maternity Home)                                          28.0
# MAT+ORTHOPEDICS                                                    27.0
# ortho.                                                             26.0
# Both                                                               25.0
# UROLOGY                                                            24.0
# pediatric                                                          15.0
# Gen                                                                15.0
# ayurved & panchkarma                                               15.0
# MATERNITY                                                          14.0
# MAT+GEN                                                            14.0
# GENRAL                                                             12.0
# sergical                                                           10.0
# GEN                                                                 9.0
# GENERAL                                                             9.0
# MAT+ GEN                                                            8.0
# OPTHLM                                                              7.0
# OPTHALMOLOGY+ENT                                                    6.0
# GENERAL+ ORTHO                                                      5.0
# opthalm                                                             5.0
# MAT+   GEN                                                          5.0
# cardiologist                                                        5.0
# IVF                                                                 4.0
# OPTHALMOLOGY                                                        4.0
# OPTHALM                                                             4.0
# MAT+ENT                                                             4.0
# OPTHAL                                                              3.0
# OPTHOLM                                                             2.0
# OPTAHL                                                              2.0
# opth.                                                               2.0
# ENT                                                                 2.0
# OPTAHLM                                                             1.0
# Dispensary (OPD - Mobile Clinic)                                    0.0
# Dispensary (OPD)                                                    0.0
# Dispensary (OPD + Immunization Centre)                              0.0

# %%
top5=avg_beds_by_types.sort_values(by="Number of Beds in facility type", ascending=False, inplace=True)
