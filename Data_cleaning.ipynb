# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/hp/Downloads/archive (6)/PMC Hospital Infrastructure.csv")
df
# Out:
#     City Name                      Zone Name                 Ward Name  \
# 0        Pune      kasba - vishrambagwada WO                Ambil Odha
# 1        Pune               Aundh - Baner WO                     Aundh
# 2        Pune               Aundh - Baner WO                    Bopodi
# 3        Pune  Ghole Road - Shivaji Nagar WO     Shivaji Nagar Station
# 4        Pune          Hadapsar - Mundhwa WO                  Hadapsar
# ..        ...                            ...                       ...
# 732      Pune                              1          DHOLE-PATIL ROAD
# 733      Pune                              1  NAGAR ROAD- VADGOANSHERI
# 734      Pune                              3             SINGHARD ROAD
# 735      Pune                              1          DHOLE-PATIL ROAD
# 736      Pune                              4          HADAPSAR-MUNDHWA
#
#      Zone No.  Ward No.                                      Facility Name  \
# ...

# %%
df.shape
# Out:
# (737, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   City Name                              737 non-null    object
#  1   Zone Name                              705 non-null    object
#  2   Ward Name                              735 non-null    object
#  3   Zone No.                               692 non-null    float64
#  4   Ward No.                               0 non-null      float64
#  5   Facility Name                          737 non-null    object
#  6   Type  (Hospital / Nursing Home / Lab)  737 non-null    object
#  7    Class : (Public / Private)            737 non-null    object
#  8   Pharmacy Available : Yes/No            737 non-null    object
#  9   Number of Beds in Emergency Wards      737 non-null    object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     City Name                      Zone Name                 Ward Name  \
# 0        Pune      kasba - vishrambagwada WO                Ambil Odha
# 1        Pune               Aundh - Baner WO                     Aundh
# 2        Pune               Aundh - Baner WO                    Bopodi
# 3        Pune  Ghole Road - Shivaji Nagar WO     Shivaji Nagar Station
# 4        Pune          Hadapsar - Mundhwa WO                  Hadapsar
# ..        ...                            ...                       ...
# 732      Pune                              1          DHOLE-PATIL ROAD
# 733      Pune                              1  NAGAR ROAD- VADGOANSHERI
# 734      Pune                              3             SINGHARD ROAD
# 735      Pune                              1          DHOLE-PATIL ROAD
# 736      Pune                              4          HADAPSAR-MUNDHWA
#
#      Zone No.  Ward No.                                      Facility Name  \
# ...

# %%
df.rename(columns={
    "Type '(Hospital/Nursing Home/Lab)'": "Type",
    "pharmacy available :Yes/No": "pharmacy",
    "class :public /private": "class"
}, inplace=True)
df_columns

# %%
df.head()
# Out:
#   City Name                      Zone Name              Ward Name  Zone No.  \
# 0      Pune      kasba - vishrambagwada WO             Ambil Odha       5.0
# 1      Pune               Aundh - Baner WO                  Aundh       2.0
# 2      Pune               Aundh - Baner WO                 Bopodi       2.0
# 3      Pune  Ghole Road - Shivaji Nagar WO  Shivaji Nagar Station       2.0
# 4      Pune          Hadapsar - Mundhwa WO               Hadapsar       4.0
#
#    Ward No.                                      Facility Name  \
# 0       NaN  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1       NaN                   Aundh Kuti Maternity Home, Aundh
# 2       NaN  Late Draupadabai Murlidhar Khedekar Maternity ...
# 3       NaN                       Dr. Dalvi, PMC Joint Project
# 4       NaN     Late Anna Saheb Magar Maternity Home, Hadapsar
#
#   Type  (Hospital / Nursing Home / Lab)  Class : (Public / Private)  \
# ...

# %%
df.isna().sum()
# Out:
# City Name                                  0
# Zone Name                                 32
# Ward Name                                  2
# Zone No.                                  45
# Ward No.                                 737
# Facility Name                              0
# Type  (Hospital / Nursing Home / Lab)      0
#  Class : (Public / Private)                0
# Pharmacy Available : Yes/No                0
# Number of Beds in Emergency Wards          0
# Number of Beds in facility type            0
# Number of Doctors / Physicians             0
# Number of Nurses                           0
# Number of Midwives Professional            0
# Average Monthly Patient Footfall           3
# Ambulance Service Available                0
# Count of Ambulance                         0
# dtype: int64

# %%
df.drop("Ward No.", axis=1, inplace=True)
df.head()
# Out:
#   City Name                      Zone Name              Ward Name  Zone No.  \
# 0      Pune      kasba - vishrambagwada WO             Ambil Odha       5.0
# 1      Pune               Aundh - Baner WO                  Aundh       2.0
# 2      Pune               Aundh - Baner WO                 Bopodi       2.0
# 3      Pune  Ghole Road - Shivaji Nagar WO  Shivaji Nagar Station       2.0
# 4      Pune          Hadapsar - Mundhwa WO               Hadapsar       4.0
#
#                                        Facility Name  \
# 0  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1                   Aundh Kuti Maternity Home, Aundh
# 2  Late Draupadabai Murlidhar Khedekar Maternity ...
# 3                       Dr. Dalvi, PMC Joint Project
# 4     Late Anna Saheb Magar Maternity Home, Hadapsar
#
#   Type  (Hospital / Nursing Home / Lab)  Class : (Public / Private)  \
# 0             Hospital (Maternity Home)                      Public
# ...

# %%
df["Ambulance Service Available"] = df["Ambulance Service Available"].replace(
    {"YES": "Yes", "NA": "No"}
)
df["Pharmacy Available : Yes/No"] = df["Pharmacy Available : Yes/No"].replace(
    {"YES": "Yes", "NA": "No"}
)

# %%
cols = ["Ambulance Service Available", "Pharmacy Available : Yes/No"]

for i in cols:
    print(i)
    print(df[i].unique())
    print("------")
# Out:
# Ambulance Service Available
# ['Yes' 'No' 'N.A.']
# ------
# Pharmacy Available : Yes/No
# ['Yes' 'N.A.']
# ------
